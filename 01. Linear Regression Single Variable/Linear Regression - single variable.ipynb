# %%
pip install scikit-learn
# Out:
# Requirement already satisfied: scikit-learn in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (1.4.1.post1)
# Requirement already satisfied: numpy<2.0,>=1.19.5 in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.12.0)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (1.3.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\gshpe\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn) (3.3.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model

# %%
df = pd.read_csv('homeprices.csv')

# %%
df.head()
# Out:
#    area   price
# 0  2600  550000
# 1  3000  565000
# 2  3200  610000
# 3  3600  680000
# 4  4000  725000

# %%
# %matplotlib inline
plt.scatter(df.area, df.price)

# %%
plt.xlabel('area(sqr ft)')
plt.ylabel('price(US$)')
plt.scatter(df.area, df.price, color='red', marker = '+')

# %%
# Create an object for linear regression
reg = linear_model.LinearRegression()

# Training regression model using available data points
reg.fit(df[['area']], df.price)
# Out:
# LinearRegression()

# %%
reg.predict([[3300]])
# Out:
# C:\Users\gshpe\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([628715.75342466])

# %%
m = reg.coef_
m
# Out:
# array([135.78767123])

# %%
c = reg.intercept_
c
# Out:
# 180616.43835616432

# %%
# price = m * area + c
price = m * 3300 + c
price
# Out:
# array([628715.75342466])

# %%
plt.xlabel('area', fontsize=10)
plt.ylabel('price', fontsize=10)
plt.scatter(df.area, df.price, color='red', marker = '+')
plt.plot(df.area, reg.predict(df[['area']]), color='blue')

# %%
d = pd.read_csv('areas.csv')
d
# Out:
#     area
# 0   1000
# 1   1500
# 2   2300
# 3   3540
# 4   4120
# 5   4560
# 6   5490
# 7   3460
# 8   4750
# 9   2300
# 10  9000
# 11  8600
# 12  7100

# %%
p=reg.predict(d)
p
# Out:
# array([ 316404.10958904,  384297.94520548,  492928.08219178,
#         661304.79452055,  740061.64383562,  799808.21917808,
#         926090.75342466,  650441.78082192,  825607.87671233,
#         492928.08219178, 1402705.47945205, 1348390.4109589 ,
#        1144708.90410959])

# %%
d['prices'] = p

# %%
d
# Out:
#     area        prices
# 0   1000  3.164041e+05
# 1   1500  3.842979e+05
# 2   2300  4.929281e+05
# 3   3540  6.613048e+05
# 4   4120  7.400616e+05
# 5   4560  7.998082e+05
# 6   5490  9.260908e+05
# 7   3460  6.504418e+05
# 8   4750  8.256079e+05
# 9   2300  4.929281e+05
# 10  9000  1.402705e+06
# 11  8600  1.348390e+06
# 12  7100  1.144709e+06

# %%
d.to_csv("prediction.csv", index = False)
